# %% [markdown]
# Import Libraries

# %%
# Load the Pandas libraries - alias 'pd' 
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Uploading the dataset using Pandas

# %%
# Uploading the dataset

credit = pd.read_csv('C:\\Users\\gfrances\\Desktop\\personal\\Big-data_Analytics\\python-big-data-5\\default_of_credit_card_clients.csv', header=1, low_memory=False)

# %% [markdown]
# Preprocessing and exploring the data

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %% [markdown]
# Removing ID Column

# %%
credit = credit.drop('ID', axis=1)

# %%
credit.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# Converting to string variables

# %%
credit['SEX'] = credit['SEX'].astype('str')
credit['EDUCATION'] = credit['EDUCATION'].astype('str')
credit['MARRIAGE'] = credit['MARRIAGE'].astype('str')
credit['PAY_0'] = credit['PAY_0'].astype('str')
credit['PAY_2'] = credit['PAY_2'].astype('str')
credit['PAY_3'] = credit['PAY_3'].astype('str')
credit['PAY_4'] = credit['PAY_4'].astype('str')
credit['PAY_5'] = credit['PAY_5'].astype('str')
credit['PAY_6'] = credit['PAY_6'].astype('str')
credit['default payment next month'] = credit['default payment next month'].astype('str')

# %% [markdown]
#  Renaming Categories

# %%
credit.loc[credit['SEX'].str.contains('1'),'SEX'] = 'Male'
credit.loc[credit['SEX'].str.contains('2'),'SEX'] = 'Female'

# %%
credit.loc[credit['MARRIAGE'].str.contains('0'),'MARRIAGE'] = 'Others'
credit.loc[credit['MARRIAGE'].str.contains('1'),'MARRIAGE'] = 'Married'
credit.loc[credit['MARRIAGE'].str.contains('2'),'MARRIAGE'] = 'Single'
credit.loc[credit['MARRIAGE'].str.contains('3'),'MARRIAGE'] = 'Divorce'

# %%
credit.loc[credit['EDUCATION'].str.contains('0'),'EDUCATION'] = 'Others'
credit.loc[credit['EDUCATION'].str.contains('1'),'EDUCATION'] = 'Graduate school'
credit.loc[credit['EDUCATION'].str.contains('2'),'EDUCATION'] = 'University'
credit.loc[credit['EDUCATION'].str.contains('3'),'EDUCATION'] = 'High School'
credit.loc[credit['EDUCATION'].str.contains('4'),'EDUCATION'] = 'Others'
credit.loc[credit['EDUCATION'].str.contains('5'),'EDUCATION'] = 'Others'
credit.loc[credit['EDUCATION'].str.contains('6'),'EDUCATION'] = 'Others'

# %%
credit.loc[credit['default payment next month'].str.contains('1'),'default payment next month'] = 'Default'
credit.loc[credit['default payment next month'].str.contains('0'),'default payment next month'] = 'Not default'

# %%
credit.loc[credit['PAY_0'].str.contains('-2'),'PAY_0'] = 'No consumption'
credit.loc[credit['PAY_0'].str.contains('-1'),'PAY_0'] = 'Paid in full'
credit.loc[credit['PAY_0'].str.contains('0'),'PAY_0'] = 'The use of revolving credit'
credit.loc[credit['PAY_0'].str.contains('1'),'PAY_0'] = 'Payment delay for one month'
credit.loc[credit['PAY_0'].str.contains('2'),'PAY_0'] = 'Payment delay for two months'
credit.loc[credit['PAY_0'].str.contains('3'),'PAY_0'] = 'Payment delay for three months'
credit.loc[credit['PAY_0'].str.contains('4'),'PAY_0'] = 'Payment delay for four months'
credit.loc[credit['PAY_0'].str.contains('5'),'PAY_0'] = 'Payment delay for five months'
credit.loc[credit['PAY_0'].str.contains('6'),'PAY_0'] = 'Payment delay for six months'
credit.loc[credit['PAY_0'].str.contains('7'),'PAY_0'] = 'Payment delay for seven months'
credit.loc[credit['PAY_0'].str.contains('8'),'PAY_0'] = 'Payment delay for eight months'
credit.loc[credit['PAY_0'].str.contains('9'),'PAY_0'] = 'Payment delay for nine months and above'

# %%
credit.loc[credit['PAY_2'].str.contains('-2'),'PAY_2'] = ' No consumption'
credit.loc[credit['PAY_2'].str.contains('-1'),'PAY_2'] = 'Paid in full'
credit.loc[credit['PAY_2'].str.contains('0'),'PAY_2'] = 'The use of revolving credit'
credit.loc[credit['PAY_2'].str.contains('1'),'PAY_2'] = 'Payment delay for one month'
credit.loc[credit['PAY_2'].str.contains('2'),'PAY_2'] = 'Payment delay for two months'
credit.loc[credit['PAY_2'].str.contains('3'),'PAY_2'] = 'Payment delay for three months'
credit.loc[credit['PAY_2'].str.contains('4'),'PAY_2'] = 'Payment delay for four months'
credit.loc[credit['PAY_2'].str.contains('5'),'PAY_2'] = 'Payment delay for five months'
credit.loc[credit['PAY_2'].str.contains('6'),'PAY_2'] = 'Payment delay for six months'
credit.loc[credit['PAY_2'].str.contains('7'),'PAY_2'] = 'Payment delay for seven months'
credit.loc[credit['PAY_2'].str.contains('8'),'PAY_2'] = 'Payment delay for eight months'
credit.loc[credit['PAY_2'].str.contains('9'),'PAY_2'] = 'Payment delay for nine months and above'

# %%
credit.loc[credit['PAY_3'].str.contains('-2'),'PAY_3'] = ' No consumption'
credit.loc[credit['PAY_3'].str.contains('-1'),'PAY_3'] = 'Paid in full'
credit.loc[credit['PAY_3'].str.contains('0'),'PAY_3'] = 'The use of revolving credit'
credit.loc[credit['PAY_3'].str.contains('1'),'PAY_3'] = 'Payment delay for one month'
credit.loc[credit['PAY_3'].str.contains('2'),'PAY_3'] = 'Payment delay for two months'
credit.loc[credit['PAY_3'].str.contains('3'),'PAY_3'] = 'Payment delay for three months'
credit.loc[credit['PAY_3'].str.contains('4'),'PAY_3'] = 'Payment delay for four months'
credit.loc[credit['PAY_3'].str.contains('5'),'PAY_3'] = 'Payment delay for five months'
credit.loc[credit['PAY_3'].str.contains('6'),'PAY_3'] = 'Payment delay for six months'
credit.loc[credit['PAY_3'].str.contains('7'),'PAY_3'] = 'Payment delay for seven months'
credit.loc[credit['PAY_3'].str.contains('8'),'PAY_3'] = 'Payment delay for eight months'
credit.loc[credit['PAY_3'].str.contains('9'),'PAY_3'] = 'Payment delay for nine months and above'

# %%
credit.loc[credit['PAY_4'].str.contains('-2'),'PAY_4'] = ' No consumption'
credit.loc[credit['PAY_4'].str.contains('-1'),'PAY_4'] = 'Paid in full'
credit.loc[credit['PAY_4'].str.contains('0'),'PAY_4'] = 'The use of revolving credit'
credit.loc[credit['PAY_4'].str.contains('1'),'PAY_4'] = 'Payment delay for one month'
credit.loc[credit['PAY_4'].str.contains('2'),'PAY_4'] = 'Payment delay for two months'
credit.loc[credit['PAY_4'].str.contains('3'),'PAY_4'] = 'Payment delay for three months'
credit.loc[credit['PAY_4'].str.contains('4'),'PAY_4'] = 'Payment delay for four months'
credit.loc[credit['PAY_4'].str.contains('5'),'PAY_4'] = 'Payment delay for five months'
credit.loc[credit['PAY_4'].str.contains('6'),'PAY_4'] = 'Payment delay for six months'
credit.loc[credit['PAY_4'].str.contains('7'),'PAY_4'] = 'Payment delay for seven months'
credit.loc[credit['PAY_4'].str.contains('8'),'PAY_4'] = 'Payment delay for eight months'
credit.loc[credit['PAY_4'].str.contains('9'),'PAY_4'] = 'Payment delay for nine months and above'

# %%
credit.loc[credit['PAY_5'].str.contains('-2'),'PAY_5'] = ' No consumption'
credit.loc[credit['PAY_5'].str.contains('-1'),'PAY_5'] = 'Paid in full'
credit.loc[credit['PAY_5'].str.contains('0'),'PAY_5'] = 'The use of revolving credit'
credit.loc[credit['PAY_5'].str.contains('1'),'PAY_5'] = 'Payment delay for one month'
credit.loc[credit['PAY_5'].str.contains('2'),'PAY_5'] = 'Payment delay for two months'
credit.loc[credit['PAY_5'].str.contains('3'),'PAY_5'] = 'Payment delay for three months'
credit.loc[credit['PAY_5'].str.contains('4'),'PAY_5'] = 'Payment delay for four months'
credit.loc[credit['PAY_5'].str.contains('5'),'PAY_5'] = 'Payment delay for five months'
credit.loc[credit['PAY_5'].str.contains('6'),'PAY_5'] = 'Payment delay for six months'
credit.loc[credit['PAY_5'].str.contains('7'),'PAY_5'] = 'Payment delay for seven months'
credit.loc[credit['PAY_5'].str.contains('8'),'PAY_5'] = 'Payment delay for eight months'
credit.loc[credit['PAY_5'].str.contains('9'),'PAY_5'] = 'Payment delay for nine months and above'

# %%
credit.loc[credit['PAY_6'].str.contains('-2'),'PAY_6'] = ' No consumption'
credit.loc[credit['PAY_6'].str.contains('-1'),'PAY_6'] = 'Paid in full'
credit.loc[credit['PAY_6'].str.contains('0'),'PAY_6'] = 'The use of revolving credit'
credit.loc[credit['PAY_6'].str.contains('1'),'PAY_6'] = 'Payment delay for one month'
credit.loc[credit['PAY_6'].str.contains('2'),'PAY_6'] = 'Payment delay for two months'
credit.loc[credit['PAY_6'].str.contains('3'),'PAY_6'] = 'Payment delay for three months'
credit.loc[credit['PAY_6'].str.contains('4'),'PAY_6'] = 'Payment delay for four months'
credit.loc[credit['PAY_6'].str.contains('5'),'PAY_6'] = 'Payment delay for five months'
credit.loc[credit['PAY_6'].str.contains('6'),'PAY_6'] = 'Payment delay for six months'
credit.loc[credit['PAY_6'].str.contains('7'),'PAY_6'] = 'Payment delay for seven months'
credit.loc[credit['PAY_6'].str.contains('8'),'PAY_6'] = 'Payment delay for eight months'
credit.loc[credit['PAY_6'].str.contains('9'),'PAY_6'] = 'Payment delay for nine months and above'

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null object
# EDUCATION                     30000 non-null object
# MARRIAGE                      30000 non-null object
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null object
# PAY_2                         30000 non-null object
# PAY_3                         30000 non-null object
# PAY_4                         30000 non-null object
# PAY_5                         30000 non-null object
# PAY_6                         30000 non-null object
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# ...

# %% [markdown]
# Converting to categorical variables

# %%
credit['SEX'] = credit['SEX'].astype('category')
credit['EDUCATION'] = credit['EDUCATION'].astype('category')
credit['MARRIAGE'] = credit['MARRIAGE'].astype('category')
credit['PAY_0'] = credit['PAY_0'].astype('category')
credit['PAY_2'] = credit['PAY_2'].astype('category')
credit['PAY_3'] = credit['PAY_3'].astype('category')
credit['PAY_4'] = credit['PAY_4'].astype('category')
credit['PAY_5'] = credit['PAY_5'].astype('category')
credit['PAY_6'] = credit['PAY_6'].astype('category')
credit['default payment next month'] = credit['default payment next month'].astype('category')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null category
# EDUCATION                     30000 non-null category
# MARRIAGE                      30000 non-null category
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null category
# PAY_2                         30000 non-null category
# PAY_3                         30000 non-null category
# PAY_4                         30000 non-null category
# PAY_5                         30000 non-null category
# PAY_6                         30000 non-null category
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# ...

# %% [markdown]
# Getting the dataset size

# %%
credit.shape
# Out:
# (30000, 24)

# %%
credit.dtypes
# Out:
# LIMIT_BAL                        int64
# SEX                           category
# EDUCATION                     category
# MARRIAGE                      category
# AGE                              int64
# PAY_0                         category
# PAY_2                         category
# PAY_3                         category
# PAY_4                         category
# PAY_5                         category
# PAY_6                         category
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# default payment next month    category
# dtype: object

# %%
total_credits = len(credit)
print(total_credits)
# Out:
# 30000

# %% [markdown]
# ## Performing Exploratory Analysis

# %% [markdown]
# # Visualizing the data

# %% [markdown]
# Histograms

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.xlabel('Credit (US dollars)')
plt.ylabel('Frequency')
plt.title('Credit Distribution')
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
plt.xlabel('Credit (US dollars)')
plt.ylabel('Frequency')
plt.title('Credit Distribution')
plt.show()

# %% [markdown]
# Line plots

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %% [markdown]
# Scatter Plots

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Box Plots

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
#  Correlation

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#            LIMIT_BAL       AGE  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# LIMIT_BAL   1.000000  0.144713   0.285430   0.278314   0.283236   0.293988
# AGE         0.144713  1.000000   0.056239   0.054283   0.053710   0.051353
# BILL_AMT1   0.285430  0.056239   1.000000   0.951484   0.892279   0.860272
# BILL_AMT2   0.278314  0.054283   0.951484   1.000000   0.928326   0.892482
# BILL_AMT3   0.283236  0.053710   0.892279   0.928326   1.000000   0.923969
# BILL_AMT4   0.293988  0.051353   0.860272   0.892482   0.923969   1.000000
# BILL_AMT5   0.295562  0.049345   0.829779   0.859778   0.883910   0.940134
# BILL_AMT6   0.290389  0.047613   0.802650   0.831594   0.853320   0.900941
# PAY_AMT1    0.195236  0.026147   0.140277   0.280365   0.244335   0.233012
# PAY_AMT2    0.178408  0.021785   0.099355   0.100851   0.316936   0.207564
# PAY_AMT3    0.210167  0.029247   0.156887   0.150718   0.130011   0.300023
# ...

# %% [markdown]
# Covariance

# %%
covMat = credit.cov()
print(covMat)
# Out:
#               LIMIT_BAL            AGE     BILL_AMT1     BILL_AMT2  \
# LIMIT_BAL  1.683446e+10  173076.722569  2.727020e+09  2.570130e+09
# AGE        1.730767e+05      84.969755  3.817293e+04  3.561366e+04
# BILL_AMT1  2.727020e+09   38172.933546  5.422240e+09  4.986670e+09
# BILL_AMT2  2.570130e+09   35613.657962  4.986670e+09  5.065705e+09
# BILL_AMT3  2.548533e+09   34334.251320  4.556511e+09  4.582086e+09
# BILL_AMT4  2.453926e+09   30453.108180  4.075286e+09  4.086508e+09
# BILL_AMT5  2.331481e+09   27654.067800  3.714795e+09  3.720401e+09
# BILL_AMT6  2.243837e+09   26137.648547  3.519876e+09  3.524868e+09
# PAY_AMT1   4.195711e+08    3992.041735  1.710894e+08  3.305146e+08
# PAY_AMT2   5.333504e+08    4626.861549  1.685692e+08  1.653859e+08
# PAY_AMT3   4.801180e+08    4746.824393  2.034048e+08  1.888731e+08
# PAY_AMT4   4.131202e+08    3087.324192  1.826164e+08  1.643518e+08
# PAY_AMT5   4.305657e+08    3218.052172  1.879091e+08  1.717652e+08
# ...

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: SEX, dtype: int64

# %%
print(credit['SEX'].unique())
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
sex=sns.catplot('SEX', data=credit, kind='count', aspect=1.5)
ax=sex.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
sexHist=plt.hist(credit['SEX'], bins=3, color = "skyblue", ec="blue")
plt.xlabel('Gender')
plt.colorbar
plt.ylabel('Frequency')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# # Analyzing Variable distribution

# %%
credit.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# Graduate school    10585
# High School         4917
# Others               468
# University         14030
# Name: EDUCATION, dtype: int64

# %%
print(credit['EDUCATION'].unique())
# Out:
# [University, Graduate school, High School, Others]
# Categories (4, object): [University, Graduate school, High School, Others]

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: SEX, dtype: int64

# %%
print(credit['SEX'].unique())
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
credit.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# Divorce      323
# Married    13659
# Others        54
# Single     15964
# Name: MARRIAGE, dtype: int64

# %%
print(credit['MARRIAGE'].unique())
# Out:
# [Married, Single, Divorce, Others]
# Categories (4, object): [Married, Single, Divorce, Others]

# %%
credit.groupby('default payment next month')['default payment next month'].count()
# Out:
# default payment next month
# Default         6636
# Not default    23364
# Name: default payment next month, dtype: int64

# %%
print(credit['default payment next month'].unique())
# Out:
# [Default, Not default]
# Categories (2, object): [Default, Not default]

# %% [markdown]
# # Visualizing variable distribution

# %%
marriage = sns.catplot('MARRIAGE', data=credit, kind='count', aspect=1.5)
plt.title('Marital Status Distribution.')
ax=marriage.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
sex = sns.catplot('SEX', data=credit, kind='count', aspect=1.5)
plt.title('Gender Distribution.')
ax=sex.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# Female    18112
# Male      11888
# Name: SEX, dtype: int64

# %%
femalePercentage=SEX.Female.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-55883a72c513> in <module>
# ----> 1 femalePercentage=SEX.Female.count()
#
# NameError: name 'SEX' is not defined

# %%
education = sns.catplot('EDUCATION', data=credit, kind='count', aspect=1.5)
plt.title('Education Level Distribution.')
ax=education.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay0 = sns.catplot('PAY_0', data=credit, kind='count', aspect=8)
plt.title('April 2005 Pay Distribution.')
ax=pay0.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay2 = sns.catplot('PAY_2', data=credit, kind='count', aspect=8)
plt.title('May 2005 Pay Distribution.')
ax=pay2.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay3 = sns.catplot('PAY_3', data=credit, kind='count', aspect=8)
plt.title('June 2005 Pay Distribution.')
ax=pay3.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay4 = sns.catplot('PAY_4', data=credit.sort_values("PAY_4"), kind='count', aspect=8)
plt.title('July 2005 Pay Distribution.')
ax=pay4.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay5 = sns.catplot('PAY_5', data=credit, kind='count', aspect=8)
plt.title('Augoust 2005 Pay Distribution.')
ax=pay5.ax #annotate axis = seaborn axis
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay6 = sns.catplot('PAY_6', data=credit, kind='count', aspect=8)
plt.title('September 2005 Pay Distribution.')
ax=pay6.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
defaultPayment = sns.catplot('default payment next month', data=credit, kind='count', aspect=1.5)
plt.title('Payment Distribution.')
ax=defaultPayment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 150,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
sns.catplot('AGE', data=credit, kind='count', aspect=15)
plt.title('Age  Distribution.')
# Out:
# Text(0.5, 1, 'Age  Distribution.')

# %% [markdown]
# # Looking for correlation between variables and if the customer pay or not

# %%
educationvsdefault_pay_next = sns.catplot('EDUCATION', data=credit, kind='count', hue='default payment next month', aspect=1.5, order=["Graduate school","University","High School", "Others"] )
plt.title('Correlation between Education and payment status.')
ax=educationvsdefault_pay_next.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
marriagevsdefault_pay_next = sns.catplot('MARRIAGE', data=credit, kind='count', hue='default payment next month', aspect=1.5, order=["Single","Married","Divorce", "Others"])
plt.title('Correlation between marital status and payment status.')
ax=marriagevsdefault_pay_next.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
sexvsdefault_pay_next = sns.catplot('SEX', data=credit, kind='count', hue='default payment next month', aspect=1.5)
plt.title('Correlation between gender and payment status.')
ax=sexvsdefault_pay_next.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
agevsdefault_pay_next = sns.catplot('AGE', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between age and payment status.')
ax=agevsdefault_pay_next.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 25,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
gengerdistbyAge = sns.FacetGrid(credit, hue='default payment next month', aspect=4)
gengerdistbyAge.map(sns.kdeplot, 'AGE', shade=True)
maxi = credit['AGE'].max()
gengerdistbyAge.set(xlim=(0,maxi))
gengerdistbyAge.set(title='Age distribution by payment')
gengerdistbyAge.add_legend()

# %%
pay0vsdafault_payment = sns.catplot('PAY_0', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in April 2005 and payment status.')
ax=pay0vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay2vsdafault_payment = sns.catplot('PAY_2', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in May 2005 and payment status.')
ax=pay2vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
pay3vsdafault_payment = sns.catplot('PAY_3', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in June and payment status.')
ax=pay3vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
pay4vsdafault_payment = sns.catplot('PAY_4', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in July and payment status.')
pay4vsdafault_payment = sns.catplot('PAY_5', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in Augoust and payment status.')
ax=pay4vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
pay5vsdafault_payment = sns.catplot('PAY_5', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in Augoust and payment status.')
ax=pay5vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
pay6vsdafault_payment = sns.catplot('PAY_6', data=credit, kind='count', hue='default payment next month', aspect=20)
plt.title('Correlation between pay in Setember and payment status.')
ax=pay6vsdafault_payment.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# # Correlation between Independant Variables

# %%
educationvsSex = sns.catplot('EDUCATION', data=credit, kind='count', hue='SEX', aspect=3, order=["Graduate school","University","High School", "Others"])
plt.title('Number of granted credits acording to the education for each specific gender.')
ax=educationvsSex.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
credit.groupby(['SEX', 'EDUCATION'])['SEX'].count()
# Out:
# SEX     EDUCATION
# Female  Graduate school    6231
#         High School        2927
#         Others              298
#         University         8656
# Male    Graduate school    4354
#         High School        1990
#         Others              170
#         University         5374
# Name: SEX, dtype: int64

# %%
marriagevsEducation= sns.catplot('EDUCATION', data=credit, kind='count', hue='MARRIAGE', aspect=2, order=["Graduate school","University","High School", "Others"])
plt.title('Number of granted credits acording to the education in a specific marital status.')
ax=marriagevsEducation.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
credit.groupby(['MARRIAGE', 'EDUCATION'])['SEX'].count()
# Out:
# MARRIAGE  EDUCATION
# Divorce   Graduate school      50
#           High School         103
#           Others                8
#           University          162
# Married   Graduate school    3722
#           High School        2861
#           Others              234
#           University         6842
# Others    Graduate school       4
#           High School          44
#           University            6
# Single    Graduate school    6809
#           High School        1909
#           Others              226
#           University         7020
# Name: SEX, dtype: int64

# %%
marriagevsSex= sns.catplot('MARRIAGE', data=credit, kind='count', hue='SEX', aspect=2,order=["Single","Married","Divorce", "Others"])
plt.title('Number of granted credits acording to the gender in a specific marital status.')
ax=marriagevsSex.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 100,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()

# %%
credit.groupby(['MARRIAGE', 'SEX'])['SEX'].count()
# Out:
# MARRIAGE  SEX
# Divorce   Female     192
#           Male       131
# Married   Female    8469
#           Male      5190
# Others    Female      40
#           Male        14
# Single    Female    9411
#           Male      6553
# Name: SEX, dtype: int64

# %%
marriagevsSex= sns.catplot('AGE', data=credit, kind='count', hue='SEX', aspect=10)
plt.title('Age distribution by Gender.')
ax=marriagevsSex.ax #annotate axis = seaborn axis
  
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 25,
            '{:1.2f}'.format(height/total_credits*100),
            ha="center")
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
gengerdistbyAge = sns.FacetGrid(credit, hue='SEX', aspect=4)
gengerdistbyAge.map(sns.kdeplot, 'AGE', shade=True)
maxi = credit['AGE'].max()
gengerdistbyAge.set(xlim=(0,maxi))
gengerdistbyAge.set(title='Age distribution by Gender')
gengerdistbyAge.add_legend()

# %%
ageDist = credit['AGE'].dropna()
ageDistPlot = sns.distplot(ageDist)
ageDistPlot.set_title("Distribution of Credits by Age.")
# Out:
# Text(0.5, 1.0, 'Distribution of Credits by Age.')

# %%
fg=sns.factorplot('MARRIAGE', data=credit, kind='count', hue='SEX', col='default payment next month',
                 palette='Blues', order=["Single","Married","Divorce", "Others"])

# %%
fg=sns.factorplot('EDUCATION', data=credit, kind='count', hue='SEX', col='default payment next month',
                 palette='Blues', order=["Graduate school","University","High School", "Others"])
#fg.set_xlabels('Status')
